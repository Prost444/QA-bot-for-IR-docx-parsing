# %% [markdown]
# # Preliminaries Install/Import

# %%
import json
# import re
# import numpy as np 
import pandas as pd 



# import os
import ujson
import msgpack
# import logging
# import math
import multiprocessing
import sys
sys.path.append('/kaggle/input/tabert-datagen/')
# from modeling_t5dec import *
# from table import *
import time
from pathlib import Path
from typing import Dict, Optional, Iterator, Set, Tuple
# try:
#     import redis
# except:
#     !pip install redis
#     import redis
import wandb
import torch
import zmq
# from table_bert.utils import BertTokenizer
# from table_bert.config import TableBertConfig
from torch.utils.data import Dataset
# from torch.utils.data.sampler import Sampler
# import torch.distributed as dist
from tqdm import tqdm
# from table_bert.table import Column, Table
# import h5py

from datasets import Dataset
import transformers
from transformers import AutoTokenizer, EncoderDecoderModel, Seq2SeqTrainingArguments, Seq2SeqTrainer, PreTrainedTokenizerBase, GenerationConfig
import safetensors

import torch
from torch import nn
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
# from kaggle_secrets import UserSecretsClient

# user_secrets = UserSecretsClient()

# my_secret = user_secrets.get_secret("wandb_api_key") 

wandb.login(key='секрет')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Data extraction

# %%
INPUT_FILE = '/kaggle/input/ruwiki-tables-and-lists/wiki_tables_and_lists.jsonl'
df = pd.DataFrame(columns=['text', 'summary'])
NUM_SAMPLES = 10
with open(INPUT_FILE, "r", encoding="utf-8") as f:
        # Пропускаем уже обработанные таблицы
        # for _ in range(processed_tables_count):
        #     f.readline()
        n = 0
        for line in tqdm(f):
            line = line.strip()
            if not line:
                continue
            entry = json.loads(line)
            uuid = entry.get("uuid", "")
            context_before = entry.get("context_before", "") or ""
            caption = entry.get("caption", "") or ""
            header = entry.get("header", [])
            data = entry.get("data", [])

            header_names = [col["name"] for col in header]
            header_line = " | ".join(header_names)
            context_text = '\n'.join('\n'.join(inner_text) for inner_text in context_before)
            table_text = "\n".join([" | ".join([unit[1] for unit in row]) for row in data])
            # full_text = f"{context_text}\n{caption}\n{header_line}\n{table_text}".strip()
            full_text = f"{caption}\n{header_line}\n{table_text}".strip()
            df.loc[len(df)] = [table_text, context_text]
            n += 1
            if n == NUM_SAMPLES:
                break
f.close()
df.sample(5)
# Out:
# 9it [00:00, 529.54it/s]
#                                                 text  \
# 6  Соционика — типология коллективов, групп людеи...
# 1  Вильнюсский уезд\nКаунасский уезд\nКлайпедс...
# 4  основного общего образования (средняя школа) (...
# 3  Каунас (298 800);\nКлайпеда (152 000);\nШяуля...
# 5  Логотипом кофе «Гиндукуш» является слон.\nИнди...
#
#                                              summary
# 6  Предмет изучения\nОпределения предмета социони...
# 1  Территория Литвы разделена на 60 самоуправлени...
# 4  Первоначально греческое σχολή означало «досуг...
# 3  Города Литвы\nВ Литве выделяются 4 типа населе...
# 5  Образ слона в культуре\nВ русском языке слон а...

# %%
data = Dataset.from_pandas(df, preserve_index=False)
data.to_csv('data.csv')
# Out:
# Creating CSV from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 10944

# %%
# %%time
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")
# tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-uncased")
tokenizer.bos_token = tokenizer.cls_token
tokenizer.eos_token = tokenizer.sep_token
# db = TableDatabase.from_jsonl(file_path= '/kaggle/input/dataset-demo/wiki_dump.jsonl',
#                               tokenizer= tokenizer,
#                              backend='memory',
#                              num_entries= 100,
#                              num_workers= 7)
# Out:
# tokenizer_config.json:   0%|          | 0.00/24.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/642 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.65M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# CPU times: user 273 ms, sys: 71.2 ms, total: 344 ms
# Wall time: 920 ms

# %%
# %%time
def preprocess_function(examples):
    model_inputs = tokenizer(examples["text"], max_length=512, padding='max_length', truncation=True, return_tensors='pt')
    
    labels = tokenizer(text_target=examples["summary"], max_length=512, padding='max_length', truncation=True, return_tensors='pt')
    model_inputs["labels"] = labels["input_ids"]
    print(model_inputs["labels"])
    # model_inputs["labels"] = model_inputs["labels"][1:]
    return model_inputs
tokenized_data = data.map(preprocess_function, batched=True).remove_columns(['text', 'summary'])
tokenized_data.set_format(type="torch")
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]
# tensor([[   101,    843,    122,  ...,      0,      0,      0],
#         [   101,  24758,  21662,  ...,      0,      0,      0],
#         [   101,  52063,  33539,  ...,      0,      0,      0],
#         ...,
#         [   101, 118939,  53559,  ...,      0,      0,      0],
#         [   101,  80512,  20420,  ...,      0,      0,      0],
#         [   101,  23878,  16767,  ...,      0,      0,      0]])
# CPU times: user 72.2 ms, sys: 16.2 ms, total: 88.5 ms
# Wall time: 130 ms

# %%
df = pd.DataFrame(columns=['text', 'summary'])
for example in iter(db):
    table = example.get_table()
    context = ' '.join([' '.join(row) for row in example.context[0]])
    table = ' '.join([' '.join(row) for row in table.as_row_list])
    df.loc[len(df)] = [table, context]

# %%
tokenized_data = tokenized_data.train_test_split(0.2)

# %%
test_dataset = tokenized_data['test']
train_dataset, val_dataset = tokenized_data['train'].train_test_split(0.1).values()

# %% [markdown]
# # Model definition

# %%
class ChillModel(EncoderDecoderModel):
    def __init__(self,
                 config: Optional[transformers.configuration_utils.PretrainedConfig] = None,
                 encoder: Optional[transformers.modeling_utils.PreTrainedModel] = None,
                 decoder: Optional[transformers.modeling_utils.PreTrainedModel] = None):
        super(ChillModel, self).__init__(config, encoder, decoder)

    @torch.no_grad()
    def top_k_tables(query: str,
                     faiss_db,
                     k: int,
                     tokenizer: PreTrainedTokenizerBase,
                     generation_config: GenerationConfig):
        input = tokenizer(query)
        query_emb = self.encoder(**input)

        #-- find k nearest tables
        # tables, tables_emb = 
        self.decoder.generate(encoder_output= tables_emb, generation_config= generation_config)
        
        return k_nearest_tables, tables_sum

# %%
import gc
gc.collect()
torch.cuda.empty_cache()
gc.collect()

# %%
model = ChillModel.from_encoder_decoder_pretrained('DeepPavlov/rubert-base-cased', 'DeepPavlov/rubert-base-cased')
model.config.decoder_start_token_id = tokenizer.bos_token_id
model.config.eos_token_id = tokenizer.eos_token_id
model.config.pad_token_id = tokenizer.pad_token_id

if torch.cuda.device_count() > 1:
    print(f"Using {torch.cuda.device_count()} GPUs for training...")
    model = nn.DataParallel(model)
model = model.to(device)

# %% [markdown]
# # Training

# %%
# 3449dfce11d8fe7fc2b677ff852a8d36414bef0b
BATCH_SIZE = 32
NUM_EPOCHS = 1000
NAME = 'bert2bert' +f"_{BATCH_SIZE}b" + f'_{NUM_EPOCHS}e'
SAVE_DIR = './results'

training_args = Seq2SeqTrainingArguments(
    output_dir= SAVE_DIR,
    eval_strategy= 'epoch',
    prediction_loss_only= True,
    learning_rate= 2e-5,
    per_device_train_batch_size= BATCH_SIZE,
    per_device_eval_batch_size= BATCH_SIZE,
    num_train_epochs= NUM_EPOCHS,
    weight_decay= 0.01,
    remove_unused_columns= True,
    logging_strategy= 'epoch',
    save_strategy= 'epoch', 
    load_best_model_at_end= True,
    run_name= NAME,
    predict_with_generate= False,
    save_total_limit= 2)
    # auto_find_batch_size= True

trainer = Seq2SeqTrainer(model,
                         processing_class= tokenizer,
                         args= training_args,
                         train_dataset= train_dataset,
                         eval_dataset = val_dataset,
                        )
trainer.train()
trainer.state.best_model_checkpoint

# %%
model.config.begin_suppress_tokens = [model.config.decoder_start_token_id]

# %%
print(model.config.decoder_start_token_id)
print(model.config.eos_token_id)
model.config.pad_token_id

# %%
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")
tokenizer.bos_token = tokenizer.cls_token
tokenizer.eos_token = tokenizer.sep_token

# %%
generation_config = transformers.GenerationConfig(
    max_length=256,
    min_length=None,
    do_sample=False,
    early_stopping=True,
    num_beams=1,
    temperature=1,
    top_k=None,
    top_p=None,
    length_penalty=1.0,  # > 1.0 longer sequences, < 1.0 shorter sequences
    num_return_sequences=1,
    max_time=None,  # in seconds
    num_beam_groups=1,
    output_scores=False,
    bos_token_id= model.config.decoder_start_token_id,
    begin_suppress_tokens= [model.config.decoder_start_token_id])
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:638: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(

# %%
generation_config

# %%
inputs = tokenizer('Михаил Ломоносов основал МГУ', return_tensors="pt").to(device)
input_ids = inputs.input_ids
with torch.no_grad():
    emb = model.encoder(**inputs)
emb.keys()

# %%
model = EncoderDecoderModel.from_pretrained('/kaggle/input/bert2bert-4b-300e/results/checkpoint-9912').to(device)

# %%
df = pd.read_csv('/kaggle/input/scores-output/output.csv')
df.sample(3)
# Out:
#                                          Prompt  \
# 36  Список наиболее значимых битв Средневековья
# 14         Список действующих вулканов Камчатки
# 11         Списки рек, протекающих через Москву
#
#                                               Context  \
# 36  ВикипедияСтатьи годаИтоги\nНоминация «Статьи.\...
# 14  Вулканы КабоВерде\nСписок действующих и потух...
# 11  год\n* В России летом произошли природные ката...
#
#                                                Result
# 36  Из предоставленного контекста невозможно соста...
# 14  Извините, но у меня нет информации о вулканах ...
# 11  К сожалению, в предоставленном контексте нет и...

# %%
results = df['Result'].values

# %%
questions = df['Prompt'].values

# %%
# from transformers import EncoderDecoderModel, BertTokenizer
# import torch



# training

# model.config.pad_token_id = tokenizer.pad_token_id
# model.config.vocab_size = model.config.decoder.vocab_size

# input_ids = tokenizer("This is a really long text", return_tensors="pt").input_ids
# labels = tokenizer("This is the corresponding summary", return_tensors="pt").input_ids
# outputs = model(input_ids=input_ids, labels=labels)
# loss, logits = outputs.loss, outputs.logits

# save and load from pretrained
# model.save_pretrained("bert2bert")
# model = EncoderDecoderModel.from_pretrained("bert2bert")
outputs = []

for quesion in tqdm(questions):
    inputs = tokenizer(quesion, return_tensors="pt").to(device)
    with torch.no_grad():
        emb = model.encoder(**inputs).last_hidden_state
        
    # print(input_ids)
    
    # input_ids = next(iter(train_dataset))['input_ids']
    # generation
    generated = model.decoder.generate(encoder_hidden_states = emb, generation_config=generation_config)
    outputs.append(tokenizer.batch_decode(generated,  skip_special_tokens= True))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:638: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# 100%|██████████| 41/41 [02:33<00:00,  3.75s/it]

# %%
generated = tokenizer.batch_decode(generated,  skip_special_tokens= True)

# %%
try:
    from evaluate import load
except:
    # !pip install evaluate
    from evaluate import load

# %%
# !pip install bert_score
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.4.0)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.2.3)
# Requirement already satisfied: transformers>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.46.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/conda/lib/python3.10/site-packages (from bert_score) (4.66.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from bert_score) (3.7.5)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from bert_score) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->bert_score) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->bert_score) (2024.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.0.0->bert_score) (2024.6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.26.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->bert_score) (10.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bert_score) (2024.6.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13

# %%
questions[0]
# Out:
# 'Численность населения Москвы за последние 20 лет'

# %%
outputs
# Out:
# [['См. такжеПримечанияСсыл # # ки2014года2017года.2012года.2017года.2017года.2017года.2013годапо2013года —2017года.2013года —..2017года —..2017года —2017года..2017года —2017года.2017года —2017года.2017года —2017года.2017года —2017года.2017года —2017года —2017года2017года —2017года.2017года —2017года —2017года —2017года2017года —2017года2013года —2017'],
#  ['Списокгубернских Федерациивклассификации видовспортивныхобъектов, входящихв список. Списокнаселенныхобъектоввразличныхобъектахвразличныхобъектахвразличныхобъектах. СписокнаселенныхобъектоввклассификациинаселенныхобъектоввРоссии.. # # n. # # # # n # # # # # # # # # # # # # # # # # #в # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['НаградыПримечанияСсыл # # ки # # s # # s, # # os # # s1907года # # # # os # # s1907годаподназванием " # # # # # # # # " 彬 # # # # # # # # " # # # # # # # # # #.....2017года.2017года.2017года. # # # # # # # # # #2017года.1907года..2012года.2017года2017года2017года.2017года'],
#  ['Женатна актрисеХоллиМон # # ес # # е. Фильм # # ографияПримечанияСсыл # # ки # # ческаябиография # # ческаябиография # # ческаябиография # # ческаябиография # # ческаябиография.. # # ческаябиография......... # # # # # # # #2017года.... # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['Составкомандыдляучастиявконкурсе « Золотогодвени », помимоэтого, былоздесьдвух, испанскихкоманд, испанскихкомандизНидерландов, испанскихкомандизНидерландов, испанскихкомандизНидерландов, испанскихкомандиз, испанскихкомандиз, испанскихкомандиз, испанскихкомандыдвухстран, испанскихкомандизрегионов. Команды, занявшиевгруппахквалификационныхраундахвпервыхквалификационныхтурах, учитываютсявкачествеоновсехквалификационныхтурах. # # # # # #сосозда. —.собирск # # ов,.собираютсясоглас # # ные.собираютсясо.собираютсяв.собираютсяв..собираютсяв.собираютсяв.'],
#  ['В1978году вРоссиивпервыев из - за болезни. В1978годуокончил факультетИнститутамузыки. С1968года — профессор университета. С1968года — профессор истории академиинаук. С1968года — профессорВоронежскогогосударственногоуниверситета. С1971года — профессор истории университета. С1971года — профессор истории университета. С1971года — профессор истории университета. С1971года — профессорВоронежскогогосударственногоуниверситета. С1978года — профессор истории университета. С1978года — профессор истории академиинаук. С1978года — профессор истории истории академиинаук. С1978года — профессор историиРоссии. С1971года — профессор истории академиинаук. С1971года — профессор историиРоссии. С1973годапреподавалв академиинаук. Членредколлегии « Современноеисторическоеописание ». Членредколлегии « Современноеисторическоеописание ». Членредколлегии « Современноеисторическоеописание ». Членредколлегии « Современноеисторическоеописание ».'],
#  [',,,, переулок, таккак билет, выставлен # # ные, билет,, выставлен # # ным клубом,,,,,,,,,, переулок,, переулок, что билет, билет, билет., что билет, билет, билет., тоесть билет. билет, билет, билет, билет. билет. билет. билет. билет. билет. билет. билет, билет, билет. билет, билет, билет. билет, билет, билет, билет, билет, билет, билет, билет'],
#  ['СписокулицСеверо - Крымского # # ов, улица # # очная.с # # ъ # # чес # # ки.с # # ки.подс # # ки.спер # # ъ # # чес # # ки..сп # # # # # # # #сопер # # яп # #с # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['— другоеназваниекор # # истоголя, нос # # овоекняще. Нос # # ныечертыисоставленычерез, конецсоснов # # ныхчеркас. Нос # # ныечертысозданыв частичеркасяс частичеркас. Нос # # ныечертысозданыв частичеркасов....... # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['ПримечанияЛитератураСсыл # # ки # # ческая. # # # # # # # #......'],
#  ['НаградыПримечанияСсыл # # ки # # яп # # овододзанятия # # яподзанятия # # яп # # япод # # оводзанятия.подписок.подписок.подписок. # # яп # # яп # # япод # # овод # # япод # # овод # # япод # # овод. # # япод # # япод # # яподод # #скисод # # япододод. # # # # # # # # # #2016годсо # # # # # #2017годасоподписок.сосогод # # япод # # япод # # япод # #2017года'],
#  ['СинонимыПримечанияСсыл # # киref = # # лис # # ки # # ческиереки # # кис # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки.с # # ки...с # # ки..................'],
#  ['НаградыПримечанияСсыл # # ки # # сс # # овв премии премиина премииСогласн премии1982года премии1982года. премии1982года.1982года. премии1982года.1982года. # # # # # # # # # #1982года.1982года.1982года.1982года1982года1982года1982года1982года1982года'],
#  ['НаградыПримечанияСсыл # # ки # # яп # # ки2011года.2011года.2017года.....2012года.2017года —...2012года.2012года.2012года. # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['СписокулицвСм. такжеСписок пунктоввСм. такжеСписокулицвСм. такжеСписоквпарковныхпарковвСм. такженаком # # ированныхстраниц.наклад # # ныхстран. медали. медали. # # # # # # # # # # # #.. # # # # 日 # # 日 # # 日 # # 日 # # 日 # # 日 # # 日 # # 日 日 # # 日 日 日 # # 日 日 # # 日 日 日 # # 日 日 日 日 日 日 日 日 日 日 日 日 日 日 日 日 日 日 日 # #... # # # # # #'],
#  ['ПримечанияЛитератураСсыл # # ки # # 日 # # диабет # # скаяэнциклопедия # # диабет # # я....соответствиисоответствиис......................'],
#  ['См. такжеПримечанияСсыл # # ки..............................'],
#  ['СписокулицСм. такжеСписокдепутатовСм. такжеСписокдепутатовСеверо - КрымскогоСеверногоСеверногоСевера # # ческих. # # ческихбилет # # ов. # # ческихбилет # # ов. # # ческихбилет # # ов. # # ческогобилет # # ов. # #собил # # ов. # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #со1973собил # #197собил # # # # # # # # #'],
#  [', в1976году. в1976году. был в школевКалифорнии, Великобритания. в церквивСент -, Великобритания. церквиподверглись : собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор, собор. Ссыл # # ки церквивСм. также списоквСент - Петербурге..подписка.подписка.под.под'],
#  ['ПримечанияЛитератураСсыл # # киСписок # # рт # # ныеисточники # # рт # # ныесоглашенияСписок Японии. # # рт # # н # # н # # н # # ныесоглашенияСписок Япониипо Японии.сосоглашениямСписок Япониипо Японии.соглашения.сосоглас # # н # # н # # н # # рт # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # н # # ы'],
#  ['См. такжеПримечанияСсыл # # ки # # ческая # # ческая # # яп # # рик # # та # # та # # цу # # то # # то # # та. # # яп # # то # # то # # та. # # цу # # то # # та. # # яп # # та # # та.. # # яп # #гата # #гата # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # яп # # япод # # япод # # япод # # япод # # япод # # япод # # япод # # япод # # яп # # яп # # япод # # яп # # яп # # яп # # япод # # яп # # япод # # яп # # япод # # вид # # вид # # вид'],
#  ['ПримечанияСсыл # # киСтатистикана Японии........ # #...'],
#  ['НаградыПримечанияСсыл # # ки # # рис # # ован # # наяпрография # # рис # # ована. # #190 # #подпискиСписок # #1919191919года # # # # # # # # # # # # # # # #сопер # # щ # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['ПримечанияЛитератураСсыл # # ки « ».пись # # яп # # ми # # я »..письпись # # яп # # я # # яс # # я.состав # # ит # # яс # # я.письпись # # яп # # яс # # я.письпись # # яп # # яс # # я.пись # # яп # # яп # # я.пись # # яп # # я.пись # # яп # # яп # # яЯс # # яп # # яп # # яп # # я. # # яп # # яп # # япод # # япод # # яп # # япод # # япод # # япод # # япод # # яп # # япод # # яп # # яп # # япод # # япод # # япод # # яподс # # яподс # # япод # # яп'],
#  ['«'],
#  ['См. такжеПримечанияСсыл # # ки # # яп # # я..................... # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['В1941годуокончил факультет университета. УчаствовалввосновномвРиге. В1941 — 1944годахсовершенствовал # # сяв школе. В1942 — 1944годахсовершенствовал # # сяв школеNo12. В1944 — 1945годахсовершенствовал # # сяв школеNo12. В1945 — 1946гг. — профессорВосковскогоуниверситета. ЧленБКПс1945года. НаградыОрденЛенина192сопере197года полк ( # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['См. такжеПримечанияСсыл # # ки # # 一пон # # онд # # онд # # онд # # онд # # онд # # я ( 日 ) ( ). # # # # онд # # онд # # онд # # онд # # онд # # онд # # онд # # онд # # онд ). # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['См. такжеПримечанияСсыл # # киВладимирКолес # # ов # # яп # # ских. # # яп # # ски # # ских... # # # # яп # # ски # # ски # # ски # # скиеДэв # # скив,.....вор # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  [',,, переулок # # яп # # ки,, улица. # # яп # # ки, улица, улица,, яп # # ки, улица,,,,,,,,,, # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['. Ссыл # # киИнтервьюИнтервьюсоответствен # # ныдлясозданиясозданиясофт # # бол # # ов « »........соответствии # #соответительсосоответительсососо'],
#  ['— турнирпо средимужчин. Проводятсяс1939года. Победителии # # ческих.. # # # # # #. # # # # # # # # # # # # # # # #. # # # # # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 一 # # 一 一 # # 一 一 一 一 一 一 一 一 一 一 一 一 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一 # # 一'],
#  ['комплекс « Центр » строитсявРоссии, вРоссии, России. Основныецентрыясписок — Центр « Центр ». # # яп # # ки. # # яп # # ки. # # яп # # ки. # # яп # # ки. # # яп # # ки. # # яп # # ки. # #со # # яп # # ки.. # # # # # # # # # # # # # # # # # # # # # # # # # # 日 # # 日 # # 日 # # 日 # # 日 # # 日со # # 積 # # 日со # # 日со # # 積 # # 日со.создка. # # # # 日 # # 日'],
#  ['— улусвКях # # тин # # е. # # яп # # ки.. # # яп # # ки.. # # яп # # ки. # # яп # # ки.сосоглас # # ки.соглас # # ки.сосоглас # # ки.соглас # # ки.соглас # # ки.со.собирск # # ки.сосогласк # # ки.согласк # # ки.согласк # # ки.согласк # # ки..соглас # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['См. такжеПримечанияСсыл # # киСвято - # # ческаягазета # # ческаягазета # # ческаягазета # # # # # # ческаяКазахстан...........................'],
#  ['. Составсоставляет310 # # 4согласных. # # ческих.. # # яп # # ских. # # скиреконы. # # яп # # ских.согласныесоглас # # ныесоглас # # ныесогласныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ныесогласк # # ысогласк # # ысогласк # # ысогласк # # ысогласк # # ысогласк # # ныесогласк # # ныесогласк # # ныесо'],
#  ['См. такжеПримечанияСсыл # # киОснов # # ныесочиненияОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбществоОбщество # # ныесочиненияСписок # # чес # # чес # # ки.подписи.. # # # # ς # # ς # # ς # # # # ς # # ς # # ς # # ς # # ς # # ς # # ς # # ς # # ς # # ς # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['В1952годуорганизм « Союзперво # # мст # # ителя » был изпервыхвРоссиипроизводстве « ». В1952годуорганизм « Союздох » был вРоссиипроизводстве бронетехники, используемыхвмашине, средствахсредства, длямашин, противотанковыхракет, противотанковыхракет, противотанковыхракетныхракет. В1952году « Союз » был вВторуюочередьс вРоссиивнедрениекоторого. В1952годуорганизацию « Союздооружения » былосоздано совет, в1952году — совет. В1952годуорганизациюсостоялкомитет, был в совет. В1952годуорганизациюсостоялось16руководящих, включая8, которыебылисозданывСоветеМинистерстваобороныиСоветаСоветаМинистровСоветаМинистровСоветаМинистровСоветаМинистровСоветаСоветаМинистровСоветаСоветаМинистровСоветаМинистровСоветаСоветаМинистровСовет'],
#  [',,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,'],
#  ['НаградыПримечанияСсыл # # ки # # рт # # овв2011году премиив2011году. премиив2011году. премиив2011году.содатель # # s # #содатель # # скив2012году. премиив2012году. премиив2012году..... # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #'],
#  ['Общаясуммация системывключаетвсебя : Структурасистемы системывключает : наличиев структуресистемы, подвержен # # ныхвмира # # х различногоразнообразия.спр # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас # # ас #']]

# %%
bertscore = load("bertscore")
predictions, references = [o[0] for o in outputs], questions

bs = bertscore.compute(predictions=predictions, references=references, lang="ru")

# %%
print('precision', sum(bs['precision'])/len(bs['precision']))
print('recall', sum(bs['recall'])/len(bs['recall']))
print('f1', sum(bs['f1'])/len(bs['f1']))
# Out:
# precision 0.41671923166368063
# recall 0.5871573090553284
# f1 0.48525058496289136

# %%
from ignite.metrics import Rouge
m = Rouge(variants=["L"], multiref="average")


m.update((predictions, references))

print(m.compute())
# Out:
# {'Rouge-L-P': 0.0031532775377011084, 'Rouge-L-R': 0.7919307892145258, 'Rouge-L-F': 0.7919307892145258}

# %%
# tokenizer.batch_decode(generated, skip_special_tokens= True)

# %%
 # [tokenizer.decode(t, skip_special_tokens=True) for t in generated]

# %%
# ''.join(tokenizer.convert_ids_to_tokens(generated[0]))
